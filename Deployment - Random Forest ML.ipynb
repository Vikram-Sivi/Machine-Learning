# %%
import pickle

# %%
loaded_model=pickle.load(open('Finalized_Model_RF.sav','rb'))
result=loaded_model.predict([[200500,300500,400500,400500,500500,200500]])
result
# Out:
# C:\Users\HP\Anaconda3\lib\site-packages\sklearn\base.py:451: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   "X does not have valid feature names, but"
# array([184502.9137])
